# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\sales.csv")
df
# Out:
#    id   item  quantity  price       timestamp
# 0   1  Bread         3    2.5  10-07-25 09:00
# 1   2   Milk         2    1.8  10-07-25 09:15
# 2   3   Eggs         1    3.0  10-07-25 09:30

# %%
df.info()

# %%
df.head()

# %%
df.tail(2)

# %%
df.describe()

# %%
import pandas as pd
df2 = pd.read_csv(r"C:\Users\user\Desktop\Data sets\supermarket.csv")
df2

# %%
country_state = df2[["Country", "State", "Customer ID"]]
country_state

# %%
high_sales = df2[df2["Sales"] > 200]
high_sales

# %%
average_sales = df2["Sales"].mean()
average_sales

# %%
min_sale = df2["Sales"].min()
min_sale

# %%
middle_sales = df2[(df2["Sales"] > 300) & (df2["Sales"] < 500)]
middle_sales

# %%
df2.isnull().sum()

# %%
missing_rows = df2[df2["Postal Code"].isnull()]
print(missing_rows)

# %%
print(df2.isnull().sum())

# %%
# %pip install numpy

# %%
import pandas as pd
df2 = pd.read_csv(r"C:\Users\user\Desktop\Data sets\supermarket.csv")
import numpy as np
arr = np.array(df2["Sales"])
arr

# %%
min = arr.min()

mean = arr.mean()
max = arr.max()
print(min, mean ,max)

# %%
import matplotlib.pyplot as plt
import numpy as np
Order_array = np.array(df2["Order Date"])
Order_array
Sales_array = np.array(df2["Sales"])
Sales_array 
plt.plot(Order_array, Sales_array)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Category_array = np.array(df2['Category'])
Category_array
Sales_array = np.array(df2["Sales"])
Sales_array 
plt.bar(Category_array, Sales_array)
plt.title("Total amount of Sales per category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

number_of_sales_per_category = df2['Category'].value_counts()
plt.bar(number_of_sales_per_category.index, number_of_sales_per_category.values)
plt.title("Number of sales per category")
plt.xlabel('Category')
plt.ylabel('Number of sales')
plt.show()

sales_per_category = df2.groupby("Category")["Sales"].sum()
print(sales_per_category)

# %%
Category_array = np.array(df2['Category'])
Category_array
Sales_array = np.array(df2["Sales"])
Sales_array 
plt.scatter(Category_array, Sales_array)
plt.show()

# %% [markdown]
# Choosing the right chart:
# Trend over time >> Line plot
# Comparing categories >> Bar chart
# Distribution of values >> Histogram
# Relationship btn 2 variables >> Scatter plot
# Spread + outliers >> Box and whiskers plot

# %%
import pandas as pd
df3 = pd.read_csv(r"C:\Users\user\Desktop\Data sets\sales_data.csv")
df3
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...
